# %% [markdown]
# team name: neighborhood navigators

# %%
import pandas as pd
data = pd.read_csv("8d76ac6b-5ae8-4428-82a4-043130d17b02.csv"
data = data.groupby("neighborhood").count(),  index_col="neighborhood", parse_dates=True

# %%
data.head(10)
# Out:
#                           _id     call_no  incident_type  \
# neighborhood
# NaN                         1  F160029985          111.0
# NaN                         2  F180022058          111.0
# NaN                         3  F180022102          131.0
# Fineview                    4  F170043431          131.0
# Fairywood                   5  F180021111          111.0
# South Side Flats            6  F180021782          150.0
# Allegheny Center            7  F180022495          113.0
# Lincoln-Lemington-Belmar    8  F180022546          111.0
# Carrick                     9  F180022773          111.0
# Beechview                  10  F170044316          131.0
#
#                                              type_description  \
# neighborhood
# NaN                                             Building fire
# NaN                                             Building fire
# NaN                                    Passenger vehicle fire
# ...

# %%
data = data.groupby("neighborhood").count()
# Out:
#                      _id  call_no  incident_type  type_description  address  \
# neighborhood
# Allegheny Center      62       62             61                62       62
# Allegheny West        43       43             43                43       43
# Allentown            127      127            127               127      127
# Arlington             51       51             51                51       51
# Arlington Heights     13       13             13                13       13
# ...                  ...      ...            ...               ...      ...
# Upper Lawrenceville   52       52             52                52       52
# West End              23       23             23                23       23
# West Oakland          62       62             62                62       62
# Westwood              28       28             28                28       28
# Windgap               23       23             23                23       23
#
# ...
